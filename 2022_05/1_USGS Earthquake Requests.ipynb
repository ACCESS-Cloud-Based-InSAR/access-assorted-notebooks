# %%
import pandas as pd
import geopandas as gpd
import requests
import json
from shapely.geometry import shape
from rasterio.crs import CRS
from datetime import datetime, timedelta
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import concurrent.futures

# %% [markdown]
# # Getting Data
#
# ## Example

# %%
def get_eq_data(start_date: datetime,
                end_date: datetime,
                alert: str = None) -> dict:
    
    if alert is not None:
        assert(alert in ['red', 'yellow', 'orange', 'green'])
    url = r"https://earthquake.usgs.gov/fdsnws/event/1/query?"
    params = {"format": "geojson", 
              "starttime": str(start_date), 
              "endtime": str(end_date),
              "alertlevel": alert
             }
    resp = requests.get(url, params=params)
    if resp.status_code != 200:
        raise ValueError(resp.text)
    return resp.json()

# %%
start_date = datetime(2021, 1, 1)
end_date = datetime(2021, 2, 1)
alert = 'green'

resp = get_eq_data(start_date, 
                   end_date,
                   alert)
len(resp['features'])
# Out:
# 65

# %%
def format_data(data: dict) -> gpd.GeoDataFrame:
    if not data['features']:
        return gpd.GeoDataFrame()
    geometry = [shape(f['geometry']) for f in data['features']]
    properties = [f['properties'] for f in data['features']]
    df = gpd.GeoDataFrame(properties, 
                          geometry=geometry, 
                          crs=CRS.from_epsg(4326))
    df['depth'] = df.geometry.apply(lambda x: x.coords[0][2])
    return df

# %%
df = format_data(resp)
df.head()
# Out:
#    mag                                  place           time        updated  \
# 0  4.9       84 km SSE of Bengkulu, Indonesia  1612003951473  1618599748040
# 1  5.7                 northwest of Australia  1611949675783  1618599741040
# 2  5.4                 South Shetland Islands  1611929439666  1618599738040
# 3  5.5  12 km WSW of Puerto Armuelles, Panama  1611926084617  1618599736040
# 4  5.7   12 km SW of Puerto Armuelles, Panama  1611924098711  1619853098423
#
#      tz                                                url  \
# 0  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi    mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  2.7  3.207  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   1.0  5.7  3.911  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  3.672  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   4.0  5.2  6.059  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...  16.0  6.6  6.375  ...
#
#                                                types nst   dmin   rms    gap  \
# 0        ,dyfi,losspager,origin,phase-data,shakemap, NaN  0.479  0.57   31.0
# 1  ,dyfi,internal-origin,losspager,moment-tensor,... NaN  4.131  0.98   24.0
# 2             ,losspager,origin,phase-data,shakemap, NaN  1.661  0.63   54.0
# 3  ,dyfi,losspager,moment-tensor,origin,phase-dat... NaN  0.390  0.63  117.0
# 4  ,dyfi,internal-origin,losspager,moment-tensor,... NaN  0.419  0.68   79.0
#
#   magType        type                                          title  \
# 0     mww  earthquake       M 4.9 - 84 km SSE of Bengkulu, Indonesia
# 1     mww  earthquake                 M 5.7 - northwest of Australia
# 2     mww  earthquake                 M 5.4 - South Shetland Islands
# 3     mww  earthquake  M 5.5 - 12 km WSW of Puerto Armuelles, Panama
# 4     mww  earthquake   M 5.7 - 12 km SW of Puerto Armuelles, Panama
#
#                                  geometry  depth
# 0   POINT Z (102.50480 -4.52950 54.90000)   54.9
# 1  POINT Z (121.86410 -13.96720 10.00000)   10.0
# 2  POINT Z (-55.30650 -61.73930 10.00000)   10.0
# 3    POINT Z (-82.96690 8.23410 10.00000)   10.0
# 4     POINT Z (-82.95000 8.20450 8.00000)    8.0
#
# [5 rows x 28 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5), dpi=200)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='black', zorder=1, alpha=.1)

df.plot(ax=ax)
ax.set_ylim(-90, 90)
ax.set_xlim(-180, 180)
# Out:
# (-180.0, 180.0)

# %% [markdown]
# ## All data

# %%
start_date_all = datetime(2014, 1, 1)
end_date_all = datetime(2022, 6, 1)
alerts_all = ['red', 'yellow', 'orange', 'green']

# %%
N = int(np.ceil((end_date_all - start_date_all).days / 30))
step = 30

dates = [(start_date_all + timedelta(days=(k * step)), 
          start_date_all + timedelta(days=((k+1) * step))) for k in range(N)]
inputs = [[start, end, alert] for alert in alerts_all for (start, end) in dates]

# %%
json_data = [get_eq_data(start, end, alert) for (start, end, alert) in tqdm(inputs)]

## Don't use multithread because you will get error of too many requests
## https://geohazards.usgs.gov/pipermail/realtime-feeds/2022-January/000028.html
# with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
#     json_data = list(tqdm(executor.map(lambda i: get_eq_data(*i), inputs), total=len(inputs)))

len(json_data)
# Out:
# 100%|██████████| 412/412 [03:10<00:00,  2.17it/s]
# 412

# %%
dfs = [format_data(d) for d in tqdm(json_data)]
df = pd.concat(dfs, axis=0)
# Out:
# 100%|██████████| 412/412 [00:06<00:00, 64.88it/s]

# %%
fig, ax = plt.subplots(figsize=(20, 5), dpi=200)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='black', zorder=1, alpha=.1)

for alert in alerts_all:
    df[df.alert==alert].plot(ax=ax, 
                             label=f'{alert.capitalize()}',
                             color=alert,
                             alpha=.3
                             )

ax.set_ylim(-90, 90)
ax.set_xlim(-180, 180)
ax.legend(bbox_to_anchor=(1.0, .5), prop={'size': 10}, title='Alert status')
ax.set_title('Earthquakes Since 2014')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
# Out:
# Text(1195.0786450101873, 0.5, 'Latitude')

# %%
fig, ax = plt.subplots(figsize=(20, 5), dpi=200)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot(ax=ax, color='black', zorder=1, alpha=.1)

df_f = df[(df.mag > 6) & (df.depth < 30)].reset_index()
for alert in ['green', 'orange', 'red']:
    df_f[df_f.alert==alert].plot(ax=ax, 
                                 label=f'{alert.capitalize()}',
                                 color=alert,
                                 alpha=.3
                                 )

ax.set_ylim(-90, 90)
ax.set_xlim(-180, 180)
ax.legend(bbox_to_anchor=(1.0, .5), prop={'size': 10}, title='Alert status')
ax.set_title('Earthquakes Since 2014 (Magnitude > 6 and Depth < 30 km)')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
# Out:
# Text(1232.023950586513, 0.5, 'Latitude')
